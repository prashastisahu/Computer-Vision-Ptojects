# %%
x = "hello world"
print(x)
print('Type of x:', type(x))
# Out:
# hello world
# Type of x: <class 'str'>

# %%
x+= ',Welcome here!'
print(x)
# Out:
# hello world,Welcome here!,Welcome here!

# %%
a = [1,2,5,4]

# %%
print(a[-1])
# Out:
# 4

# %%
print(a)
# Out:
# [2]
